# %% [markdown]
#  <h1 style="font-size:44px;color:#064e3b;">MozEconomia Chatbot</h1>

# %%
with open("ZMMIREFR.pdf", 'r') as open_file:
    print('ZMMIREFR.pdf content:\n' + open_file.read())
# Out:
# ZMMIREFR.pdf content:
# %PDF-1.3
# %âãÏÓ
# 2 0 obj
# /WinAnsiEncoding
# endobj
# 3 0 obj
# <<
# %Devtype POST2    Font COURIER  normal Lang PT
# /Type /Font
# /Subtype /Type1
# /BaseFont /Courier
# /Name /F001
# /Encoding 2 0 R
# >>
# endobj
# 4 0 obj
# <<
# /Length 5 0 R
# >>
# stream
#  /F001 11.50 Tf 0 0 0.753 rg BT 18.00 706.15 Td 0 Tw <2020202020202020202020202020202020202020202020202020202042414E434F204445204D4FC7414D4249515545>Tj ET 0 0 0.753 rg BT 18.00 682.95 Td 0 Tw
#  <202020202020202020202020202020202054415841532044452043C24D42494F53204445205245464552CA4E43494120454D204D45544943414953>Tj ET 0 0 0.753 rg BT 18.00 659.75 Td 0 Tw
#  <202020202020202020202020424F4C4554494D2044452043C24D42494F532041205649474F52415220454D3A203232206465204A554C484F20646520323032>Tj ET 0 0 0.753 rg BT 452.70 659.75 Td 0 Tw <32>Tj ET 0 0 0.753 rg BT 18.00 648.15 Td 0 Tw
# ...

# %%
with open("ZMMIREFR.pdf", 'r') as open_file:
    for observation in open_file:
        print(observation)
# Out:
# %PDF-1.3
#
# %âãÏÓ
#
# 2 0 obj
#
# /WinAnsiEncoding
#
# endobj
#
# 3 0 obj
#
# <<
#
# %Devtype POST2    Font COURIER  normal Lang PT
#
# /Type /Font
#
# /Subtype /Type1
#
# /BaseFont /Courier
#
# /Name /F001
#
# /Encoding 2 0 R
#
# >>
#
# endobj
#
# 4 0 obj
#
# <<
#
# /Length 5 0 R
#
# >>
#
# stream
#
#  /F001 11.50 Tf 0 0 0.753 rg BT 18.00 706.15 Td 0 Tw <2020202020202020202020202020202020202020202020202020202042414E434F204445204D4FC7414D4249515545>Tj ET 0 0 0.753 rg BT 18.00 682.95 Td 0 Tw
#
#  <202020202020202020202020202020202054415841532044452043C24D42494F53204445205245464552CA4E43494120454D204D45544943414953>Tj ET 0 0 0.753 rg BT 18.00 659.75 Td 0 Tw
#
#  <202020202020202020202020424F4C4554494D2044452043C24D42494F532041205649474F52415220454D3A203232206465204A554C484F20646520323032>Tj ET 0 0 0.753 rg BT 452.70 659.75 Td 0 Tw <32>Tj ET 0 0 0.753 rg BT 18.00 648.15 Td 0 Tw
#
# ...

# %%
import pandas as pd
table = pd.read_json("exchanges.json").values

print(table)
# Out:
# [['Estados Unidos' 'https://flagcdn.com/w20/us.png' 'US Dollar'
#   {'code': 'USD', 'number': '840'}
#   {'major': {'name': 'dollar', 'symbol': '$'}, 'minor': {'name': 'cent', 'symbol': '¢', 'majorValue': 0.01}}
#   {'frequent': ['$1', '$5', '$10', '$20', '$50', '$100'], 'rare': ['2$']}
#   {'frequent': ['1¢', '5¢', '10¢', '25¢'], 'rare': ['$1', '50¢']}
#   {'buy': 63.23, 'sale': 64.49, 'date': '2022-07-25 09:00'} list([])]
#  ['Àfrica do Sul' 'https://flagcdn.com/w20/za.png' 'South African Rand'
#   {'code': 'ZAR', 'number': '710'}
#   {'major': {'name': 'Rand', 'symbol': 'R'}, 'minor': {'name': 'cent', 'symbol': 'c', 'majorValue': 0.01}}
#   {'frequent': ['R10', 'R20', 'R50', 'R100', 'R200'], 'rare': []}
#   {'frequent': ['R1', 'R2', 'R5', '5c', '10c', '20c'], 'rare': []}
#   {'buy': 3.75, 'sale': 3.83, 'date': '2022-07-25 09:00'} list([])]
#  ['Emirados Árabes Unidos' 'https://flagcdn.com/w20/ae.png'
#   'Emirati Dirham' {'code': 'AED', 'number': '784'}
# ...

# %%
import pandas as pd

xlsx = pd.ExcelFile("balanca-de-pagamento.xlsx")

trig_values = xlsx.parse('Planilha2', index_col=None, na_values=['NA'])

print(trig_values)
# Out:
#    Valor Líquido em Milhões de USD  Unnamed: 1  Unnamed: 2  Unnamed: 3  \
# 0                              Ano      2005.0      2006.0      2007.0
# 1                             Bens         NaN         NaN         NaN
# 2                       Exportação      1745.3      2381.1      2412.1
# 3                       Importação      2242.3      2648.8      2811.1
# 4                         Serviços         NaN         NaN         NaN
# 5                          crédito       341.9       386.3       458.7
# 6                           débito       648.6       758.1       855.5
# 7            Rendimentos Primários         NaN         NaN         NaN
# 8                          crédito        98.9       159.8       193.6
# 9                           débito       458.8       794.3       785.2
# 10      Transferências Unilaterais         NaN         NaN         NaN
# 11                         crédito       479.0       574.5       657.8
# ...

# %%
from skimage.io import imread
from skimage.transform import resize
from matplotlib import pyplot as plt
import matplotlib.cm as cm
example_file = ("http://upload.wikimedia.org/wikipedia/commons/7/7d/Dog_face.png")
image = imread(example_file, as_grey=True)
plt.imshow(image, cmap=cm.gray)
plt.show()
# Out:
# Matplotlib is building the font cache; this may take a moment.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [20], in <cell line: 6>()
#       4 import matplotlib.cm as cm
#       5 example_file = ("http://upload.wikimedia.org/wikipedia/commons/7/7d/Dog_face.png")
# ----> 6 image = imread(example_file, as_grey=True)
#       7 plt.imshow(image, cmap=cm.gray)
#       8 plt.show()
#
# File C:\ProgramData\Anaconda3\lib\site-packages\skimage\io\_io.py:53, in imread(fname, as_gray, plugin, **plugin_args)
#      50         plugin = 'tifffile'
#      52 with file_or_url_context(fname) as fname:
# ---> 53     img = call_plugin('imread', fname, plugin=plugin, **plugin_args)
#      55 if not hasattr(img, 'ndim'):
#      56     return img
#
# File C:\ProgramData\Anaconda3\lib\site-packages\skimage\io\manage_plugins.py:207, in call_plugin(kind, *args, **kwargs)
# ...
